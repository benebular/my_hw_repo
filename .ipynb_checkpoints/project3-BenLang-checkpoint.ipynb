# %% [markdown]
# # Project 3
#
# In this project, you will perform a logistic regression on the admissions data we've been working with in projects 1 and 2.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import statsmodels.api as sm
import pylab as pl
import numpy as np

# %%
df_raw = pd.read_csv("../my_hw_repo/admissions.csv")
df = df_raw.dropna() 
print df.head()
# Out:
#    admit    gre   gpa  prestige
# 0      0  380.0  3.61       3.0
# 1      1  660.0  3.67       3.0
# 2      1  800.0  4.00       1.0
# 3      1  640.0  3.19       4.0
# 4      0  520.0  2.93       4.0

# %% [markdown]
# ## Part 1. Frequency Tables
#
# #### 1. Let's create a frequency table of our variables

# %%
# frequency table for prestige and whether or not someone was admitted
# df = df[['admit','prestige']]
# df = pd.set_index(df)
frequency_table = pd.crosstab(df['admit'], df['prestige'], dropna=True)
print frequency_table
# Out:
# prestige  1.0  2.0  3.0  4.0
# admit
# 0          28   95   93   55
# 1          33   53   28   12

# %% [markdown]
# ## Part 2. Return of dummy variables

# %% [markdown]
# #### 2.1 Create class or dummy variables for prestige

# %%
df = pd.get_dummies(df, columns=['prestige'])
df
# Out:
#      admit    gre   gpa  prestige_1.0  prestige_2.0  prestige_3.0  \
# 0        0  380.0  3.61             0             0             1
# 1        1  660.0  3.67             0             0             1
# 2        1  800.0  4.00             1             0             0
# 3        1  640.0  3.19             0             0             0
# 4        0  520.0  2.93             0             0             0
# 5        1  760.0  3.00             0             1             0
# 6        1  560.0  2.98             1             0             0
# 7        0  400.0  3.08             0             1             0
# 8        1  540.0  3.39             0             0             1
# 9        0  700.0  3.92             0             1             0
# 10       0  800.0  4.00             0             0             0
# 11       0  440.0  3.22             1             0             0
# 12       1  760.0  4.00             1             0             0
# ...

# %% [markdown]
# #### 2.2 When modeling our class variables, how many do we need?

# %% [markdown]
# Answer: We always need n-1. In this ccase, Prestige has four ranks and so we need 3 dummy variables.

# %% [markdown]
# ## Part 3. Hand calculating odds ratios
#
# Develop your intuition about expected outcomes by hand calculating odds ratios.

# %%
# cols_to_keep = ['admit', 'gre', 'gpa']
# handCalc = df[cols_to_keep].join(dummy_ranks.ix[:, 'prestige_1':])
# print handCalc.head()

#IGNORING because the .get_dummies function changed and already does this above
df
# Out:
#      admit    gre   gpa  prestige_1.0  prestige_2.0  prestige_3.0  \
# 0        0  380.0  3.61             0             0             1
# 1        1  660.0  3.67             0             0             1
# 2        1  800.0  4.00             1             0             0
# 3        1  640.0  3.19             0             0             0
# 4        0  520.0  2.93             0             0             0
# 5        1  760.0  3.00             0             1             0
# 6        1  560.0  2.98             1             0             0
# 7        0  400.0  3.08             0             1             0
# 8        1  540.0  3.39             0             0             1
# 9        0  700.0  3.92             0             1             0
# 10       0  800.0  4.00             0             0             0
# 11       0  440.0  3.22             1             0             0
# 12       1  760.0  4.00             1             0             0
# ...

# %%
#crosstab prestige 1 admission 
# frequency table cutting prestige and whether or not someone was admitted

frequency_table_prestige_1 = pd.crosstab(df['admit'], df['prestige_1.0'], dropna=True)
print frequency_table_prestige_1
# Out:
# prestige_1.0    0   1
# admit
# 0             243  28
# 1              93  33

# %% [markdown]
# #### 3.1 Use the cross tab above to calculate the odds of being admitted to grad school if you attended a #1 ranked college

# %%
yes_admit = 33./28
print yes_admit
# Out:
# 1.17857142857

# %% [markdown]
# #### 3.2 Now calculate the odds of admission if you did not attend a #1 ranked college

# %%
no_admit = 93./243
print no_admit
# Out:
# 0.382716049383

# %% [markdown]
# #### 3.3 Calculate the odds ratio

# %%
yes_admit/no_admit
# Out:
# 3.079493087557604

# %% [markdown]
# #### 3.4 Write this finding in a sentenance:

# %% [markdown]
# Answer: Answer: The odds of being admitted into a high-ranking university for graduate school based on the high ranking of an individual's undergraduate university education is 3.08.

# %% [markdown]
# #### 3.5 Print the cross tab for prestige_4

# %%
frequency_table_prestige_4 = pd.crosstab(df['admit'], df['prestige_4.0'], dropna=True)
print frequency_table_prestige_4
# Out:
# prestige_4.0    0   1
# admit
# 0             216  55
# 1             114  12

# %% [markdown]
# #### 3.6 Calculate the OR

# %%
y_admit = 12./55
n_admit = 114./216

or_prestige4 = y_admit/n_admit
print or_prestige4
# Out:
# 0.413397129187

# %% [markdown]
# #### 3.7 Write this finding in a sentence

# %% [markdown]
# Answer: The odds of being admitted into a high-ranking university for graduate school based on the low ranking of an individual's undergraduate university education is 0.41.

# %% [markdown]
# ## Part 4. Analysis

# %%
# create a clean data frame for the regression
# cols_to_keep = ['admit', 'gre', 'gpa']
# data = df[cols_to_keep].join(dummy_ranks.ix[:, 'prestige_2':])
# print data.head()

# IGNORING AGAIN because we have one from above. However, removing the first now that we are running the regression.
del df['prestige_1.0']
df
# Out:
#      admit    gre   gpa  prestige_2.0  prestige_3.0  prestige_4.0
# 0        0  380.0  3.61             0             1             0
# 1        1  660.0  3.67             0             1             0
# 2        1  800.0  4.00             0             0             0
# 3        1  640.0  3.19             0             0             1
# 4        0  520.0  2.93             0             0             1
# 5        1  760.0  3.00             1             0             0
# 6        1  560.0  2.98             0             0             0
# 7        0  400.0  3.08             1             0             0
# 8        1  540.0  3.39             0             1             0
# 9        0  700.0  3.92             1             0             0
# 10       0  800.0  4.00             0             0             1
# 11       0  440.0  3.22             0             0             0
# 12       1  760.0  4.00             0             0             0
# ...

# %% [markdown]
# We're going to add a constant term for our Logistic Regression. The statsmodels function we're going to be using requires that intercepts/constants are specified explicitly.

# %%
# manually add the intercept
df['intercept'] = 1.0
df
# Out:
#      admit    gre   gpa  prestige_2.0  prestige_3.0  prestige_4.0  intercept
# 0        0  380.0  3.61             0             1             0        1.0
# 1        1  660.0  3.67             0             1             0        1.0
# 2        1  800.0  4.00             0             0             0        1.0
# 3        1  640.0  3.19             0             0             1        1.0
# 4        0  520.0  2.93             0             0             1        1.0
# 5        1  760.0  3.00             1             0             0        1.0
# 6        1  560.0  2.98             0             0             0        1.0
# 7        0  400.0  3.08             1             0             0        1.0
# 8        1  540.0  3.39             0             1             0        1.0
# 9        0  700.0  3.92             1             0             0        1.0
# 10       0  800.0  4.00             0             0             1        1.0
# ...

# %% [markdown]
# #### 4.1 Set the covariates to a variable called train_cols

# %%
train_cols = df.columns[1:]

# %% [markdown]
# #### 4.2 Fit the model

# %%
logit = sm.Logit(df['admit'], df[train_cols])
result = logit.fit()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.573854
#          Iterations 6

# %% [markdown]
# #### 4.3 Print the summary results

# %%
print result.summary()
# Out:
#                            Logit Regression Results
# ...
# Dep. Variable:                  admit   No. Observations:                  397
# Model:                          Logit   Df Residuals:                      391
# Method:                           MLE   Df Model:                            5
# Date:                Thu, 30 Mar 2017   Pseudo R-squ.:                 0.08166
# Time:                        23:30:17   Log-Likelihood:                -227.82
# converged:                       True   LL-Null:                       -248.08
#                                         LLR p-value:                 1.176e-07
# ...
#                    coef    std err          z      P>|z|      [95.0% Conf. Int.]
# --------------------------------------------------------------------------------
# gre              0.0022      0.001      2.028      0.043      7.44e-05     0.004
# gpa              0.7793      0.333      2.344      0.019         0.128     1.431
# ...

# %% [markdown]
# #### 4.4 Calculate the odds ratios of the coeffiencents and their 95% CI intervals
#
# hint 1: np.exp(X)
#
# hint 2: conf['OR'] = params
#
#            conf.columns = ['2.5%', '97.5%', 'OR']

# %%
print np.exp(result.params)
# Out:
# gre             1.002221
# gpa             2.180027
# prestige_2.0    0.506548
# prestige_3.0    0.262192
# prestige_4.0    0.211525
# intercept       0.020716
# dtype: float64

# %%
params = result.params
conf = result.conf_int()
conf['OR'] = params
conf.columns = ['2.5%', '97.5%', 'OR']
print np.exp(conf)
# Out:
#                   2.5%     97.5%        OR
# gre           1.000074  1.004372  1.002221
# gpa           1.136120  4.183113  2.180027
# prestige_2.0  0.272168  0.942767  0.506548
# prestige_3.0  0.133377  0.515419  0.262192
# prestige_4.0  0.093329  0.479411  0.211525
# intercept     0.002207  0.194440  0.020716

# %% [markdown]
# #### 4.5 Interpret the OR of Prestige_2

# %% [markdown]
# Answer: The odds of being admitted into the graduate school of a high-ranking university are likely, representing a 0.51 chance, based on a slightly lower rank of undergraduate university than the baseline.

# %% [markdown]
# #### 4.6 Interpret the OR of GPA

# %% [markdown]
# Answer: The odds of being admitted into the graduate school of a high-ranking university are very likely, representing a 2.18 chance, based on the gpa of an individual.

# %% [markdown]
# ## Part 5: Predicted probablities

# %% [markdown]
# As a way of evaluating our classifier, we're going to recreate the dataset with every logical combination of input values. This will allow us to see how the predicted probability of admission increases/decreases across different variables. First we're going to generate the combinations using a helper function called cartesian (above).
#
# We're going to use np.linspace to create a range of values for "gre" and "gpa". This creates a range of linearly spaced values from a specified min and maximum value--in our case just the min/max observed values.

# %%
def cartesian(arrays, out=None):
    """
    Generate a cartesian product of input arrays.
    Parameters
    ----------
    arrays : list of array-like
        1-D arrays to form the cartesian product of.
    out : ndarray
        Array to place the cartesian product in.
    Returns
    -------
    out : ndarray
        2-D array of shape (M, len(arrays)) containing cartesian products
        formed of input arrays.
    Examples
    --------
    >>> cartesian(([1, 2, 3], [4, 5], [6, 7]))
    array([[1, 4, 6],
           [1, 4, 7],
           [1, 5, 6],
           [1, 5, 7],
           [2, 4, 6],
           [2, 4, 7],
           [2, 5, 6],
           [2, 5, 7],
           [3, 4, 6],
           [3, 4, 7],
           [3, 5, 6],
           [3, 5, 7]])
    """

    arrays = [np.asarray(x) for x in arrays]
    dtype = arrays[0].dtype

    n = np.prod([x.size for x in arrays])
    if out is None:
        out = np.zeros([n, len(arrays)], dtype=dtype)

    m = n / arrays[0].size
    out[:,0] = np.repeat(arrays[0], m)
    if arrays[1:]:
        cartesian(arrays[1:], out=out[0:m,1:])
        for j in xrange(1, arrays[0].size):
            out[j*m:(j+1)*m,1:] = out[0:m,1:]
    return out

# %%
# instead of generating all possible values of GRE and GPA, we're going
# to use an evenly spaced range of 10 values from the min to the max 
gres = np.linspace(df['gre'].min(), df['gre'].max(), 10)
print gres
# array([ 220.        ,  284.44444444,  348.88888889,  413.33333333,
#         477.77777778,  542.22222222,  606.66666667,  671.11111111,
#         735.55555556,  800.        ])
gpas = np.linspace(df['gpa'].min(), df['gpa'].max(), 10)
print gpas
# array([ 2.26      ,  2.45333333,  2.64666667,  2.84      ,  3.03333333,
#         3.22666667,  3.42      ,  3.61333333,  3.80666667,  4.        ])


# enumerate all possibilities
combos = pd.DataFrame(cartesian([gres, gpas, [1, 2, 3, 4], [1.]]))
# Out:
# [ 220.          284.44444444  348.88888889  413.33333333  477.77777778
#   542.22222222  606.66666667  671.11111111  735.55555556  800.        ]
# [ 2.26        2.45333333  2.64666667  2.84        3.03333333  3.22666667
#   3.42        3.61333333  3.80666667  4.        ]

# %% [markdown]
# #### 5.1 Recreate the dummy variables

# %%
# recreate the dummy variables
combos.columns = ['gre', 'gpa', 'prestige', 'intercept']
dummy_ranks = pd.get_dummies(combos['prestige'], prefix='prestige')
dummy_ranks.columns = ['prestige_1.0', 'prestige_2.0', 'prestige_3.0', 'prestige_4.0']
# keep only what we need for making predictions
cols_to_keep = ['gre', 'gpa', 'prestige', 'intercept']
combos = combos[cols_to_keep].join(dummy_ranks.ix[:, 'prestige_2':])

# %% [markdown]
# #### 5.2 Make predictions on the enumerated dataset

# %%
combos['admit_pred'] = result.predict(combos[train_cols])

print combos.head()
# Out:
#      gre       gpa  prestige  intercept  prestige_2.0  prestige_3.0  \
# 0  220.0  2.260000       1.0        1.0             0             0
# 1  220.0  2.260000       2.0        1.0             1             0
# 2  220.0  2.260000       3.0        1.0             0             1
# 3  220.0  2.260000       4.0        1.0             0             0
# 4  220.0  2.453333       1.0        1.0             0             0
#
#    prestige_4.0  admit_pred
# 0             0    0.164173
# 1             0    0.090492
# 2             0    0.048977
# 3             1    0.039890
# 4             0    0.185907

# %% [markdown]
# #### 5.3 Interpret findings for the last 4 observations

# %% [markdown]
# Answer: Prestige ranking has the most effect on the last four observations. It is the best predictor of admission in this case, although the prediction scores themselves are relatively low. That being said, cases in which Prestige is ranked at 1 (the highest) demonstrate the highest predictive score, meaning that the higher ranked undergraduate universities positively impact the likelihood of admittance into a graduate school.

# %% [markdown]
# ## Bonus
#
# Plot the probability of being admitted into graduate school, stratified by GPA and GRE score.
