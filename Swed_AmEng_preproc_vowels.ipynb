# %%
# %matplotlib inline
#import necessary modules and tell matplotlib to print inline
import pandas as pd
import sklearn.linear_model as lm
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
import pylab as pl
import numpy as np
from sklearn.linear_model import LogisticRegression

# %%
df = pd.read_excel('/Users/ben/Documents/Github/my_hw_repo/benfinal_GAedit.xls') #importing excel of all raw data
data = df #changing data name so we don't modify original data
#following line deletes unnecessary data for current exploration
data = data.drop(['Comment','hiV','Coronal','FileNum','Midpoint','Duration','Outliers','Comment_Num','GrLangAge','SubGroup'],1)
data #show the data
# Out:
#      Subject Group Language   Word PhonemeOrig  Phoneme     F1      F2  \
# 0         AL     C  English   bets           eh      3h  508.9  1740.6
# 1         AL     C  English  debts           eh      3h  552.7  1810.8
# 2         AL     C  English   jets           eh      3h  495.7  1656.9
# 3         AL     C  English   peck           eh      3h  538.1  1685.1
# 4         AL     C  English   said           eh      3h  465.5  1677.5
# 5         AL     C  English   shed           eh      3h  498.6  1657.3
# 6         AM     C  English   bets           eh      3h  568.1  1967.1
# 7         AM     C  English  debts           eh      3h  574.5  1965.0
# 8         AM     C  English   jets           eh      3h  510.5  1944.4
# 9         AM     C  English   peck           eh      3h  650.2  1775.4
# 10        AM     C  English   said           eh      3h  527.3  1942.9
# 11        AM     C  English   shed           eh      3h  582.3  1865.9
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4136 entries, 0 to 4135
# Data columns (total 12 columns):
# Subject         4136 non-null object
# Group           4136 non-null object
# Language        4136 non-null object
# Word            4136 non-null object
# PhonemeOrig     4136 non-null object
# Phoneme         4136 non-null object
# F1              4136 non-null float64
# F2              4136 non-null float64
# F3              4136 non-null float64
# F1nearey        4136 non-null float64
# F2nearey        4136 non-null float64
# F3nearey        4136 non-null float64
# dtypes: float64(6), object(6)
# memory usage: 387.8+ KB
